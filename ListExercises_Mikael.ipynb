# %%
furniture = ["table", "chair", "shelf", "sofa"]

print(furniture)

print(furniture[0])
print(furniture[1])

for item in furniture:
    if item == "sofa":
        print(item)
# Out:
# ['table', 'chair', 'shelf', 'sofa']
# table
# chair
# sofa

# %%
from random import randint

thrownDiceNumbers = [8, 6, 3, 7, 2]

print(thrownDiceNumbers)

total = 0
for num in thrownDiceNumbers:
    total += num
print(total)

print(max(thrownDiceNumbers))
# Out:
# [8, 6, 3, 7, 2]
# 26
# 8
