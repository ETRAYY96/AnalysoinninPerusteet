# %%
number1 = 5
number2 = 5

# %%
if number1 == number2:
    print("number1 is equal to number2")
# Out:
# number1 is equal to number2

# %%
if number1 > number2:
    print("number1 is more than number2")

# %%
if number1 >= number2:
    print("number1 is more than or equal to number2")
# Out:
# number1 is more than or equal to number2

# %%
if number1 != number2:
    print("number1 is not the same as number2")

# %%
number1 = 8
number2 = 8
number3 = 8

# %%
if number1 == number2 and number2 == number3:
    print("all numbers are the same")
# Out:
# all numbers are the same

# %%
if number1 == number2 or number2 == number3:
    print("Either number1 and number2 or number2 and number3 are equal")
# Out:
# Either number1 and number2 or number2 and number3 are equal

# %%
if number1 > number2 and number1 > number3:
    print("number1 is bigger than 2 or 3")

# %%
if number1 > number2:
    print("number1 is more than number2")
else:
     if number2 > number3:
      print("number2 is more than number3")

# %%
if number1 == number2:
    print("number1 and number2 are the same")
else:
    if number1 == number3:
        print("number1 and number3 are the same")
# Out:
# number1 and number2 are the same

# %%
name1 = "Mikael"
name2 = "Pekka"
name3 = "Markku"

# %%
if name1 == name2:
    print("name1 and name2 are the same")

# %%
if name1 != name2:
    print("name1 and name2 are not the same")
# Out:
# name1 and name2 are not the same

# %%
if name1 == name2:
    print("name1 and name2 are the same")
else:
    if name1 == name3:
        print("name1 and name3 are the same")
