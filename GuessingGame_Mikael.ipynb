# %%
#Ilman looppia
rightName = "Mikael"
guess = input("Guess the name: ")

if guess == rightName:
    print("Correct")
else:
    print("axse46gWrong")
# Out:
# Correct

# %%
#Loopin kanssa
rightName = "Mikael"
guess = ""
while guess != rightName:
    guess = input("Guess the name: ")
    if guess == rightName:
        print("Correct")
# Out:
# Correct
